# %%
def info_std(*name ):

    print(f" my name is {name } ")

# %%
info_std("mona" , "aya" )
# Out:
#  my name is mona,  my age is aya

# %%
def info_std(*name ):

    print(f" my name is {name } ")

# %%
info_std ("mona" , "aya" )
# Out:
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
#  my name is ('mona', 'aya')
# ...

# %%
def info(*age):
    print(f"my age is {age}")
    print(type(age))

# %%
info(10 , 20 , 30)
# Out:
# my age is (10, 20, 30)

# %%
type(info)
# Out:
# function

# %%
def func_1(**name):
      print(f"my name is {name}")

# %%
func_1(mona = 20, aya = 25)
# Out:
# my name is {'mona': 20, 'aya': 25}

# %%
sum_n = lambda x : x+10
type(sum_n)
sum_n(10)
# Out:
# 20

# %%
def sum(x):
    return lambda x :x + 10

# %%
sum(10)
# Out:
# <function __main__.sum.<locals>.<lambda>(x)>

# %%
sum
# Out:
# <function __main__.sum(x)>

# %%
sum_1 = lambda x,y : x+y
sum_1(10 , 20)
# Out:
# 30

# %%
def sum_2 (x , y):
    return x + y

# %%
sum_2(10 , 20)
# Out:
# 30

# %%
sum_1 = lambda x,y : x+y
sum_1(10 , 20)
# Out:
# 30

# %%
def r(val):
    lambda x : val + x

# %%
r(10)

# %%
def sum_n(n):
    return lambda a : a*n

# %%
sum_n(11)
# Out:
# <function __main__.sum_n.<locals>.<lambda>(a)>

# %%
fun_1 = sum_n(11)
fun_1(2)
# Out:
# 22

# %%
x = 0

# %%
5 / x
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 5 / x
#
# ZeroDivisionError: division by zero

# %%
try:
    5/0
except Exception as e:
    print(e)
# Out:
# division by zero

# %%
try:
    x=10
    y= int(input("enter your value"))
    x/y
except:
    print("Not accept to be devided by zero")
# Out:
# Not accept to be devided by zero

# %%
from info import info_std
info_std()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 from info import info_std
#       2 info_std()
#
# ImportError: cannot import name 'info_std' from 'info' (c:\Users\Domain\Desktop\New folder\Depi_Amit_AI_BNS3\Depi_Amit_AI_BNS3\Sources\info.py)

# %%
a = 5
y = 10
try:
  5/0
except NameError:
    print("aaaaaaaa")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[58], line 4
#       2 y = 10
#       3 try:
# ----> 4   5/0
#       5 except NameError:
#       6     print("aaaaaaaa")
#
# ZeroDivisionError: division by zero

# %%
import random

n = random.random()
def calc_degree(n):
    return n*n
calc_degree(n)
# Out:
# 0.3015044908115993

# %%
list_1 = ["ahmed" , "ali","shahinda" , "omar"]
random.choice(list_1)
# Out:
# 'shahinda'

# %%
import os

# %%
file = os.listdir("C:/Users/Domain/Desktop/New folder/Depi_Amit_AI_BNS3/Depi_Amit_AI_BNS3/Sources/Env_Setup/test.txt")
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 file = os.listdir("C:/Users/Domain/Desktop/New folder/Depi_Amit_AI_BNS3/Depi_Amit_AI_BNS3/Sources/Env_Setup/test.txt")
#
# NotADirectoryError: [WinError 267] The directory name is invalid: 'C:/Users/Domain/Desktop/New folder/Depi_Amit_AI_BNS3/Depi_Amit_AI_BNS3/Sources/Env_Setup/test.txt'

# %%
file = os.listdir("")
